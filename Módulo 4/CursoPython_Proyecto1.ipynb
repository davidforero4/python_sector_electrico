# %% [markdown]
# Los siguientes datos fueron extraídos de Coes, y corresponden a la demanda máxima de Perú entre los años 2019 y 2024, organizados por mes:
#
# ```python
# demanda= [
#   [6876.2929, 7070.6296, 6909.6383, 7070.2818, 7294.2364, 7632.532], # enero
# [6949.9979, 7125.2999, 6778.3834, 7146.7653, 7397.2595, 7761.9898], # febrero
# [6990.6696, 7116.7899, 6832.6584, 7065.4232, 7583.3666, 7550.3074], # marzo
# [6917.7406, 5173.4896, 6808.8535, 7137.4916, 7605.9395, 7548.0172], # abril
# [6884.7481, 5682.0384, 6869.711, 6961.3683, 7342.6968, 7431.311], # mayo
# [6793.7691, 6101.7817, 6903.8394, 7069.9089, 7314.6051, 7347.4927], #junio
# [6739.2817, 6383.0872, 6855.7857, 7113.7584, 7280.2124, 7416.907], # julio
# [6728.4809, 6550.7342, 6927.992, 7073.719, 7290.0389, 7447.2756], # agosto
# [6672.2767, 6607.5298, 6904.854, 7315.8018, 7374.1594, 7581.4501], # septiembre
# [6840.5684, 6835.6396, 6973.0689, 7309.359, 7354.2092, 7583.628], # octubre
# [6928.2281, 6836.6027, 7078.5258, 7426.5751, 7489.3453, 7794.0088],  #noviembre
# [7017.5721, 6960.0968, 7173.0338, 7467.4498, 7545.2823, 7698.9414] # diciembre
# ]
# ```

# %%
#Nota: Las columnas son los años, de 2019 a 2024
demanda= [
  [6876.2929, 7070.6296, 6909.6383, 7070.2818, 7294.2364, 7632.532], # enero
[6949.9979, 7125.2999, 6778.3834, 7146.7653, 7397.2595, 7761.9898], # febrero
[6990.6696, 7116.7899, 6832.6584, 7065.4232, 7583.3666, 7550.3074], # marzo
[6917.7406, 5173.4896, 6808.8535, 7137.4916, 7605.9395, 7548.0172], # abril
[6884.7481, 5682.0384, 6869.711, 6961.3683, 7342.6968, 7431.311], # mayo
[6793.7691, 6101.7817, 6903.8394, 7069.9089, 7314.6051, 7347.4927], #junio
[6739.2817, 6383.0872, 6855.7857, 7113.7584, 7280.2124, 7416.907], # julio
[6728.4809, 6550.7342, 6927.992, 7073.719, 7290.0389, 7447.2756], # agosto
[6672.2767, 6607.5298, 6904.854, 7315.8018, 7374.1594, 7581.4501], # septiembre
[6840.5684, 6835.6396, 6973.0689, 7309.359, 7354.2092, 7583.628], # octubre
[6928.2281, 6836.6027, 7078.5258, 7426.5751, 7489.3453, 7794.0088],  #noviembre
[7017.5721, 6960.0968, 7173.0338, 7467.4498, 7545.2823, 7698.9414] # diciembre
]

# %% [markdown]
# ---

# %% [markdown]
# **Ejercicio 1:** Adapte el código del ejemplo 2.15 para obtener el promedio por mes del año, y así establecer cuál es el mes de mayor demanda promedio histórico, y el de menor demanda.
#
#
# ```python
# # Ejemplo: Procesamiento de mediciones diarias
# mediciones = [
#     [218, 215, 220],  # Lunes
#     [222, 219, 225],  # Martes
#     [210, 212, 208]   # Miércoles
# ]
#
# # Calcular promedio por día
# promedios = [sum(dia)/len(dia) for dia in mediciones]
# print("Promedios diarios:", promedios)
#
# ```

# %%
# Espacio para resolver el ejercicio

# %% [markdown]
# **Ejercicio 2:** Adapte el código del Ejemplo 2.18 para determinar cuántas veces la demanda ha superado 7500:
#
# ```python
# # Matriz de covarianzas
# cov = [
#     [0.75, 0.78, 0.80],
#     [0.77, 0.82, 0.79],
#     [0.85, 0.88, 0.90]
# ]
#
# for i, fila in enumerate(cov):
#     for j, co in enumerate(fila):
#         if co > 0.85:
#             print(f" Alerta en posición ({i},{j}): {co}")
#         else:
#             print(f"Posición ({i},{j}): {co} normal")
#
#
# ```

# %%
# Espacio para resolver el ejercicio
