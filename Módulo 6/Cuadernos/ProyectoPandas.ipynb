# %% [markdown]
# # Indicaciones del proyecto:
#
# Este proyecto consiste en tomar los datos contenidos en el archivo: datos_cence.csv para obtener la siguiente información:
#
# 1. ¿En cuál de los años 2023, 2024 o 2025 se obtiene el valor promedio más alto de MW?
#
# 2. ¿En cuál mes del año 2023 ocurrió el máximo valor de MW? ¿De cuánto fue?
#
# 3. ¿En cuál mes del año 2024 ocurrió el máximo valor de MW? ¿De cuánto fue?
#
# 4. ¿En cuál mes del año 2025 ocurrió el máximo valor de MW? ¿De cuánto fue?
#
# 5. ¿En cuál mes del año 2023 se tuvo el mayor promedio de MW? ¿De cuánto fue?
#
# 6. ¿En cuál mes del año 2024 se tuvo el mayor promedio de MW? ¿De cuánto fue?
#
# 7. ¿En cuál mes del año 2024 se ha obtenido el mayor promedio de MW? ¿De cuánto fue?
#
# 8. Obtener una gráfica con todos los valores del mes de mayor consumo promedio de cada año (2023, 2024, 2025).
#
# 9. Obtener una gráfica del consumo mensual del 2023, 2024 y 2025. Poner una etiqueta en el valor máximo.**
#
# 10. Determinar si en estos datos hay anomalías.

# %% [markdown]
# ## 1. Herramientas de Pandas

# %% [markdown]
# ```python
# import pandas as pd
# import numpy as np # y Numpy...
# import matplotlib.pyplot as plt
#
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tensiones = pd.read_csv('datos_cence.csv',
                      parse_dates=['fechaHora'],
                      index_col='fechaHora')
print(tensiones.head())

# %% [markdown]
# ##Ayudas:

# %%
# datos_2023 = datos.loc['2023'].resample('Y').mean()

# %%
# datos_2023[datos_2023['MW'] == datos_2023['MW'].max()]
